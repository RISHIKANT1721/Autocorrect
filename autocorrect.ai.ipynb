# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\kantr\appdata\local\programs\python\python311\lib\site-packages (0.17.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: nltk>=3.1 in c:\users\kantr\appdata\local\programs\python\python311\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\kantr\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.1->textblob) (8.1.4)
# Requirement already satisfied: joblib in c:\users\kantr\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.1->textblob) (1.3.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kantr\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.1->textblob) (2023.6.3)
# Requirement already satisfied: tqdm in c:\users\kantr\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.1->textblob) (4.65.0)
# Requirement already satisfied: colorama in c:\users\kantr\appdata\local\programs\python\python311\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)

# %% [markdown]
# # AUTO_CORRECT_TOOL

# %%
# AUTO_CORRECT_TOOL



from tkinter import *
from textblob import TextBlob


def clearAll():


	word1_field.delete(0, END)
	word2_field.delete(0, END)




def correction():


	input_word = word1_field.get()


	blob_obj = TextBlob(input_word)


	corrected_word = str(blob_obj.correct())



	word2_field.insert(10, corrected_word)

# GUI_APPLICATION

if __name__ == "__main__":


	root = Tk()


	root.configure(background='light blue')


	root.geometry("400x200")


	root.title("Auto correct tool")


	headlabel = Label(root, text='Auto correct tool',
					fg='dark blue', bg="white")


	label1 = Label(root, text="Input Word",
				fg='red', bg='white')


	label2 = Label(root, text="Corrected Word",
				fg='red', bg='white')





	headlabel.grid(row=0, column=1)
	label1.grid(row=1, column=0)
	label2.grid(row=3, column=0, padx=10)



	word1_field = Entry()
	word2_field = Entry()


 
	word1_field.grid(row=1, column=1, padx=10, pady=10)
	word2_field.grid(row=3, column=1, padx=10, pady=10)

	
	
	button1 = Button(root, text="Correction", bg="white", fg="black",
					command=correction)

	button1.grid(row=2, column=1)

	
	
	button2 = Button(root, text="Clear", bg="white",
					fg="black", command=clearAll)

	button2.grid(row=4, column=1)

	
	root.mainloop()
